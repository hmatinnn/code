# %%
import pandas as pd
import datetime as dt
import numpy as np
import warnings

# %%
pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

# %%
sales_ = pd.read_csv('Online Retail dataset.csv') ##,encoding='unicode_escape'

# %%
sales_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
sales_.dropna(subset='CustomerID',axis=0,inplace=True) 
sales_['CustomerID'] = sales_['CustomerID'].astype('int') 
sales_['InvoiceDate'] = sales_['InvoiceDate'].astype('datetime64[ns]')
sales_.drop_duplicates()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
# [401604 rows x 8 columns]

# %%
sales_ = sales_[((sales_['Quantity']>0)&(sales_['UnitPrice']>0))&(sales_['Country']!='Unspecified')& (sales_['Country']!='European Community')] ## Removing  quantities and unitprices those are less than 0 as we shouldnt get misleading results

# %%
sales_['Monetary'] = sales_['UnitPrice']*sales_['Quantity']

# %%
last_purchase_day = sales_['InvoiceDate'].max()

# %%
rfm_table = pd.DataFrame(data = sales_.groupby(by='CustomerID').agg({'InvoiceDate': lambda x: (last_purchase_day - x.max()).days,
                                'InvoiceNo': lambda y: y.nunique(),
                                'Monetary': lambda z: z.sum()}).reset_index())

rfm_table.rename(columns={'InvoiceDate':'Recency','InvoiceNo':'Frequency'},inplace=True)

# %%
quantiles = rfm_table[['Recency','Frequency','Monetary']].quantile([0.25,0.5,0.75])

# %%
quantiles
# Out:
#       Recency  Frequency  Monetary
# 0.25     17.0        1.0    307.09
# 0.50     50.0        2.0    674.52
# 0.75    141.0        5.0   1662.28

# %%
rfm_table 
## recency < 
## frequency & monetary value >
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0          12346      325          1  77183.60
# 1          12347        1          7   4310.00
# 2          12348       74          4   1797.24
# 3          12349       18          1   1757.55
# 4          12350      309          1    334.40
# ...          ...      ...        ...       ...
# 4328       18280      277          1    180.60
# 4329       18281      180          1     80.82
# 4330       18282        7          2    178.05
# 4331       18283        3         16   2094.88
# 4332       18287       42          3   1837.28
#
# [4333 rows x 4 columns]

# %%
def FM_Score(value,q_tab,col): ##Frequency and monetary value 
    if value <= q_tab[col][0.25]: 
        return 4 
    elif value <=q_tab[col][0.5]: 
        return 3
    elif value <=q_tab[col][0.75]: 
        return 2
    else: 
        return 1

def R_Score(value,q_tab,col): ##Recency Score
    if value <= q_tab[col][0.25]: 
        return 1
    elif value <=q_tab[col][0.5]: 
        return 2
    elif value <=q_tab[col][0.75]: 
        return 3 
    else: 
        return 4

# %%
rfm_table['R_Score']  = rfm_table['Recency'].apply(R_Score,args=(quantiles,'Recency'))
rfm_table['F_Score']  = rfm_table['Frequency'].apply(FM_Score,args=(quantiles,'Frequency'))
rfm_table['M_Score']  = rfm_table['Monetary'].apply(FM_Score,args=(quantiles,'Monetary'))

# %%
def change_dtype(r_Score,f_Score,m_Score):
    return str(r_Score) + str(f_Score) + str(m_Score)

rfm_table['RFM_Score'] = np.vectorize(change_dtype)(rfm_table['R_Score'],rfm_table['F_Score'],rfm_table['M_Score'])

# %%
rfm_table
# Out:
#       CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0          12346      325          1  77183.60        4        4        1
# 1          12347        1          7   4310.00        1        1        1
# 2          12348       74          4   1797.24        3        2        1
# 3          12349       18          1   1757.55        2        4        1
# 4          12350      309          1    334.40        4        4        3
# ...          ...      ...        ...       ...      ...      ...      ...
# 4328       18280      277          1    180.60        4        4        4
# 4329       18281      180          1     80.82        4        4        4
# 4330       18282        7          2    178.05        1        3        4
# 4331       18283        3         16   2094.88        1        1        1
# 4332       18287       42          3   1837.28        2        2        1
#
#      RFM_Score
# 0          441
# 1          111
# 2          321
# 3          241
# 4          443
# ...        ...
# 4328       444
# 4329       444
# 4330       134
# 4331       111
# 4332       221
#
# [4333 rows x 8 columns]

# %%
def segment_customer(sales_):
    if sales_['R_Score'] ==1 and sales_['F_Score']==1 and sales_['M_Score'] ==1: 
        return 'Best Customers'
    elif sales_['R_Score'] ==3 and sales_['F_Score']==1 and sales_['M_Score'] ==1: 
        return 'Almost Lost'
    elif sales_['R_Score'] ==4 and sales_['F_Score']==1 and sales_['M_Score'] ==1: 
        return 'Lost Customers'
    elif sales_['R_Score'] ==4 and sales_['F_Score']==4 and sales_['M_Score'] ==4: 
        return 'Lost Cheap Customers'
    elif sales_['F_Score'] ==1: 
        return 'Loyal Customers'
    elif sales_['M_Score']==1: 
        return 'Big Spenders'
    else: 
        return 'Others'

# %%
rfm_table['Segmented'] = rfm_table.apply(segment_customer,axis=1)

# %%
rfm_table
# Out:
#       CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0          12346      325          1  77183.60        4        4        1
# 1          12347        1          7   4310.00        1        1        1
# 2          12348       74          4   1797.24        3        2        1
# 3          12349       18          1   1757.55        2        4        1
# 4          12350      309          1    334.40        4        4        3
# ...          ...      ...        ...       ...      ...      ...      ...
# 4328       18280      277          1    180.60        4        4        4
# 4329       18281      180          1     80.82        4        4        4
# 4330       18282        7          2    178.05        1        3        4
# 4331       18283        3         16   2094.88        1        1        1
# 4332       18287       42          3   1837.28        2        2        1
#
#      RFM_Score             Segmented
# 0          441          Big Spenders
# 1          111        Best Customers
# 2          321          Big Spenders
# 3          241          Big Spenders
# 4          443                Others
# ...        ...                   ...
# 4328       444  Lost Cheap Customers
# 4329       444  Lost Cheap Customers
# 4330       134                Others
# 4331       111        Best Customers
# 4332       221          Big Spenders
#
# [4333 rows x 9 columns]

# %%
rfm_table = rfm_table.merge(sales_[['CustomerID','Country']],how='inner',on='CustomerID').drop_duplicates()

# %%
cnt_customers = rfm_table.groupby(by=['Country','Segmented'])['CustomerID'].count().reset_index()
cnt_customers
# Out:
#            Country             Segmented  CustomerID
# 0        Australia        Best Customers           1
# 1        Australia          Big Spenders           1
# 2        Australia       Loyal Customers           2
# 3        Australia                Others           5
# 4          Austria          Big Spenders           3
# ..             ...                   ...         ...
# 94  United Kingdom          Big Spenders         283
# 95  United Kingdom  Lost Cheap Customers         414
# 96  United Kingdom        Lost Customers          10
# 97  United Kingdom       Loyal Customers         298
# 98  United Kingdom                Others        2432
#
# [99 rows x 3 columns]

# %%
pivot_ = pd.pivot_table(
    data=cnt_customers,columns='Country',index='Segmented',values='CustomerID',fill_value=0,margins=True,margins_name='Grand Total',aggfunc=np.sum
).sort_values('Grand Total', axis=1, ascending=False)

# %%
pivot_ = pivot_.loc[pivot_.index!='Grand Total',pivot_.columns!='Grand Total'].style.background_gradient(cmap='PuBu')

# %%
pivot_
# Out:
# <style type="text/css">
# #T_46277_row0_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T
{
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_46277_row0_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_46277_row0_col3, #T_46277_row1_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_46277_row0_col5, #T_46277_row1_col11, #T_46277_row3_col0, #T_46277_row3_col11, #T_46277_row5_col3, #T_46277_row5_col11 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_46277_row0_col16, #T_46277_row2_col16 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_46277_row0_col29, #T_46277_row1_col22, #T_46277_row1_col32, #T_46277_row2_col10, #T_46277_row2_col23, #T_46277_row2_col24, #T_46277_row2_col28, #T_46277_row3_col25, #T_46277_row3_col34, #T_46277_row6_col0, #T_46277_row6_col1, #T_46277_row6_col2, #T_46277_row6_col3, #T_46277_row6_col4, #T_46277_row6_col5, #T_46277_row6_col6, #T_46277_row6_col7, #T_46277_row6_col8, #T_46277_row6_col9, #T_46277_row6_col11, #T_46277_row6_col12, #T_46277_row6_col13, #T_46277_row6_col14, #T_46277_row6_col15, #T_46277_row6_col16, #T_46277_row6_col17, #T_46277_row6_col18, #T_46277_row6_col19, #T_46277_row6_col20, #T_46277_row6_col21, #T_46277_row6_col24, #T_46277_row6_col25, #T_46277_row6_col26, #T_46277_row6_col27, #T_46277_row6_col30, #T_46277_row6_col31, #T_46277_row6_col33 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_46277_row1_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_46277_row1_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_46277_row1_col2, #T_46277_row3_col2, #T_46277_row5_col17 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_46277_row1_col4, #T_46277_row2_col7, #T_46277_row2_col19, #T_46277_row3_col4, #T_46277_row3_col16, #T_46277_row5_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_46277_row1_col6 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_46277_row1_col7, #T_46277_row2_col0, #T_46277_row3_col3, #T_46277_row5_col7 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_46277_row1_col8, #T_46277_row2_col8 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_46277_row1_col10, #T_46277_row1_col12, #T_46277_row2_col12, #T_46277_row5_col10, #T_46277_row5_col13, #T_46277_row5_col15, #T_46277_row5_col18 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_46277_row1_col15, #T_46277_row5_col12 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_46277_row2_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_46277_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_46277_row2_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_46277_row2_col4 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_46277_row2_col5 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_46277_row2_col6 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_46277_row2_col9 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_46277_row2_col13, #T_46277_row6_col10 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_46277_row2_col14, #T_46277_row2_col20, #T_46277_row2_col22, #T_46277_row3_col20, #T_46277_row6_col23 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_46277_row2_col17 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_46277_row3_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_46277_row3_col6 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_46277_row3_col9, #T_46277_row5_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_46277_row5_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_46277_row5_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_46277_row5_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# </style>
# <table id="T_46277">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th id="T_46277_level0_col0" class="col_heading level0 col0" >United Kingdom</th>
#       <th id="T_46277_level0_col1" class="col_heading level0 col1" >Germany</th>
#       <th id="T_46277_level0_col2" class="col_heading level0 col2" >France</th>
#       <th id="T_46277_level0_col3" class="col_heading level0 col3" >Spain</th>
#       <th id="T_46277_level0_col4" class="col_heading level0 col4" >Belgium</th>
#       <th id="T_46277_level0_col5" class="col_heading level0 col5" >Switzerland</th>
#       <th id="T_46277_level0_col6" class="col_heading level0 col6" >Portugal</th>
#       <th id="T_46277_level0_col7" class="col_heading level0 col7" >Italy</th>
#       <th id="T_46277_level0_col8" class="col_heading level0 col8" >Finland</th>
#       <th id="T_46277_level0_col9" class="col_heading level0 col9" >Austria</th>
#       <th id="T_46277_level0_col10" class="col_heading level0 col10" >Norway</th>
#       <th id="T_46277_level0_col11" class="col_heading level0 col11" >Netherlands</th>
#       <th id="T_46277_level0_col12" class="col_heading level0 col12" >Australia</th>
#       <th id="T_46277_level0_col13" class="col_heading level0 col13" >Channel Islands</th>
#       <th id="T_46277_level0_col14" clas
